# %% [markdown]
# # Plot of sin(x)
# Below plot shows the sin function. The sin is the trigonomatric function whose value ranges from -1 to 1. The input of the sin can be from $-\infty$ to $\infty$.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,360,0.1)*np.pi/180
y = np.sin(x)

plt.plot(x,y,label='$sin(x)$')
plt.title('X vs $sin(x)$')
plt.grid()

plt.show()

# %%
fp1 = r'C:\Users\darsh\OneDrive - Indian Institute of Science\reference materials\Reference_images\PIV setup\liner_shape2.jpg'
arr1 = plt.imread(fp1)
plt.imshow(arr1)
plt.xticks([])
plt.yticks([])
plt.show()
